# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexis-CAPON/cse437-reinforcement-learning/blob/main/lab5_approximation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 5: Value-Function Approximation
#
#
# ## Exercise 1 SGD
# Many real-world processes can be modeled as nonlinear relationships, and SGD is a standard tool to fit those models from data.
#
# **Example: Predicting energy consumption in a building**
# - Energy usage depends on **temperature**, **time of day**, and **occupancy**.
# - If you plot the data, the relationship might not be linear — it curves.
# - A simple way to approximate this nonlinear relation is to fit a **polynomial function** of temperature (or time).
#
# Now, imagine you’re collecting data continuously:
# - You get one data point (temperature, usage) at a time.
# - Instead of waiting to collect all data and computing a full batch update, you update your model incrementally with **SGD**.
# - This makes your learning **online, adaptive, and scalable** — just like in reinforcement learning.
#
# ---
#
# In this exercise, approximating a cubic polynomial is a simplified version of **predicting a nonlinear real-world phenomenon**.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate synthetic data based on a cubic polynomial with Gaussian noise
np.random.seed(42)  # for reproducibility
n_samples = 100
x = np.linspace(-5, 5, n_samples)
# Define the true cubic polynomial function
def true_function(x):
  return 0.1 * x**3 - 0.5 * x**2 + 2 * x + 5

y_true = true_function(x)
noise = np.random.normal(0, 2, n_samples)  # Gaussian noise with mean 0 and std dev 2
y = y_true + noise

# Optional: Plot the generated data
plt.scatter(x, y, label='Generated Data')
plt.plot(x, y_true, color='red', label='True Function')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Generated Data with Cubic Polynomial and Gaussian Noise')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the given a dataset of input–output pairs `(x, y)` where the underlying relationship is approximately polynomial.
#
# a. Use a **linear model with polynomial features**: Write a function that takes an input `x` and a weight vector `w`, and return the predicted value y_hat.
#
#    - y_hat(x; w) = w0 + w1 * x + w2 * x^2 + w3 * x^3
#
#    where w0, w1, w2, w3 are the parameters to be learned.
#
# b. **Loss function (Mean Squared Error)**:
#    Write a function that computes the loss for one training point `(x, y)`:
#
#      - Formula: `loss = 0.5 * (y - y_hat)**2`
#
# c. **SGD update**:   Derive the gradient of the loss with respect to each parameter (w0, w1, w2, w3).
#    - Write a function:
#
#      ```python
#      def sgd_update(x, y, w, alpha):
#          """
#          Perform one SGD update for a single training example.
#          Input:
#              x (float) - input value
#              y (float) - true output
#              w (np.array) - current weights
#              alpha (float) - learning rate
#          Output:
#              w (np.array) - updated weights
#          """
#          # TODO: compute prediction, gradient, and update weights
#          return w
#      ```
# d. **Training loop**:
#    - Loop over the dataset.
#    - At each step, update the weights using `sgd_update`.
#    - Track the training loss after each iteration.
#
# e. **Comparison with different learning rates**
#    - Train your model using at least three different learning rates, for example:
#      - alpha = 0.001
#      - alpha = 0.01
#      - alpha = 0.1
#    - Plot training loss vs iteration for each learning rate.
#    - Plot the final fitted polynomial curves for each learning rate on the same graph with the true dataset.
#
# ---
#
# ### Deliverables
# - Code for `predict`, `mse_loss`, and `sgd_update`.
# - Training loop that runs with multiple learning rates.
# - Plot of training loss vs iteration for each learning rate.
# - Plot of the fitted polynomial vs dataset for each learning rate.
# - A short discussion:
#   - How does the learning rate affect convergence speed and stability?
#   - Which learning rate gives the best balance between speed and accuracy?

# %%
def model_predict(x, w):
  return w[0] + w[1] * x + w[2] * x**2 + w[3] * x**3

def mse_loss(y, y_hat):
  return 0.5 * (y - y_hat)**2


def sgd_update(x, y, w, alpha):
    """
    Perform one SGD update for a single training example.
    Input:
        x (float) - input value
        y (float) - true output
        w (np.array) - current weights
        alpha (float) - learning rate
    Output:
        w (np.array) - updated weights
    """
    x_normalized = x / 5.0
    y_hat = model_predict(x, w)
    w[0] += alpha * (y - y_hat) * x_normalized**0 # x**0 is 1
    w[1] += alpha * (y - y_hat) * x_normalized**1
    w[2] += alpha * (y - y_hat) * x_normalized**2
    w[3] += alpha * (y - y_hat) * x_normalized**3

    return w, y_hat

def train(X, Y, alpha, epoch):
  w = np.random.rand(4)
  training_loss = []
  for _ in range(epoch):
    for (xi, yi) in zip(X, Y):
      w, y_hat = sgd_update(xi, yi, w, alpha)
      training_loss.append(mse_loss(yi, y_hat))

  return training_loss, w


def ploting(x_data, y_data, title, x_label, y_label, label=None, true_y=None):
  plt.plot(x_data, y_data, label=label)
  if true_y is not None:
    plt.plot(x_data, true_y, color='red', label='True Function')
  plt.xlabel(x_label)
  plt.ylabel(y_label)
  plt.title(title)
  plt.legend()
  plt.grid(True)
  plt.show()

# %%
learning_rates = [0.001, 0.01, 0.1]
all_training_loss = {}
final_weights = {}
epochs = 500

for alpha in learning_rates:
  training_loss, w = train(x, y, alpha, epochs)
  plt.figure(figsize=(10, 6))
  ploting(np.arange(len(training_loss)), training_loss,  f'Training Loss vs Iteration (alpha={alpha})', 'Iteration', 'Loss', label=f'alpha={alpha}')

  y_fitted = model_predict(x, w)
  ploting(x, y_fitted, f'Fitted Polynomial vs True Function and Data (alpha={alpha})', 'x', 'y', label='Fitted Polynomial', true_y=y) # Plot fitted curve and true data
# Out:
# /tmp/ipython-input-1537631258.py:5: RuntimeWarning: overflow encountered in scalar power
#   return 0.5 * (y - y_hat)**2
# /tmp/ipython-input-1537631258.py:2: RuntimeWarning: overflow encountered in scalar add
#   return w[0] + w[1] * x + w[2] * x**2 + w[3] * x**3
# /tmp/ipython-input-1537631258.py:2: RuntimeWarning: overflow encountered in scalar multiply
#   return w[0] + w[1] * x + w[2] * x**2 + w[3] * x**3
# /tmp/ipython-input-1537631258.py:21: RuntimeWarning: invalid value encountered in scalar add
#   w[0] += alpha * (y - y_hat) * x_normalized**0 # x**0 is 1
# /tmp/ipython-input-1537631258.py:22: RuntimeWarning: invalid value encountered in scalar add
#   w[1] += alpha * (y - y_hat) * x_normalized**1
# /tmp/ipython-input-1537631258.py:23: RuntimeWarning: invalid value encountered in scalar add
#   w[2] += alpha * (y - y_hat) * x_normalized**2
# /tmp/ipython-input-1537631258.py:24: RuntimeWarning: invalid value encountered in scalar add
#   w[3] += alpha * (y - y_hat) * x_normalized**3
# /usr/local/lib/python3.12/dist-packages/matplotlib/ticker.py:2176: RuntimeWarning: overflow encountered in multiply
#   steps = self._extended_steps * scale

# %% [markdown]
# **How does the learning rate affect convergence speed and stability?**
# A lower learning rate make a better convergence speed and stability but too much lower make it slower to converge
#
# **Which learning rate gives the best balance between speed and accuracy?**
# 0.01 is the best

# %% [markdown]
# ## Exercise 2: 1000-State Random Walk with Semi-Gradient TD(0)
#
# We will study the 1,000-state Random Walk a classic reinforcement learning benchmark from Sutton & Barto.
#
# - The environment has states numbered **1 to 1000**.
# - There are two **terminal states**:
#   - State `0` on the left (reward = 0)
#   - State `1001` on the right (reward = 1)
# - Each episode starts in the **middle** at state `500`.
# - At each step, the agent moves **left or right with equal probability (0.5 each)**.
# - The episode ends when the agent reaches either terminal.
# - Discount factor: **γ = 1.0** (episodic task).
#
#
# ### Function Approximation
# Instead of storing a separate value for each state, approximate the value function with a **linear function of the state index**: V_hat(s; w0, w1) = w0 + w1 * s
#
#
#
# ---
#
# ## Instructions
# 1. **Implement the environment**:
#    - You may **use AI tools such as ChatGPT** to generate the environment code (states, transitions, rewards).
#    - Make sure you understand how the environment works.
#
# 2. **Implement the TD(0) update manually**:
#    - Do **not** use AI for this part.
#    - You must write the gradient update equations yourself using the formulas above.
#
# 3. **Train your agent**:
#    - Run several episodes (e.g., 1000 episodes).
#    - Experiment with different step sizes (`alpha`).
#
# 4. **Evaluate**:
#    - Plot the **true value function** `V*(s) = s/1001`.
#    - Plot your **learned approximation line** after training.
#    - Discuss whether the line captures the overall trend of the true values.
#
# ---
#
#
# ## Guidelines on Using AI Tools
# - You are encouraged to use AI tools (e.g., ChatGPT, Gemini, Copilot) to **generate helper code**, such as:
#   - Building the random walk environment (`reset`, `step`).
#   - Implementing the feature map φ(s).
#   - Plotting results.
# - However, **do not use AI tools to generate the TD(0) update equation**.
#   - Deriving and implementing the update is the key learning objective of this exercise.
#   - If we find code that uses an AI-generated update without understanding, the score will be zero.
#
#
# ## Deliverables
# - Python code for the environment and the TD(0) algorithm.
# - Plot the **true value function**: For state `s`, the probability of reaching the right terminal is:
#   `V*(s) = s / 1001`
# - Plot comparing the true value function and the approximated line.
# - A short discussion:
#   - How does the approximation behave for small vs large states?
#   - How does the learning rate affect convergence?
#
# ---
#
# ## Hints
# - Normalize states to `[0,1]` before using them in the line approximation to avoid very large values for w1.
# - Start with small step sizes (e.g., 0.001–0.01).
# - The approximation will not be perfect (a line cannot match the true curve), but should capture the increasing trend.

# %%
import numpy as np

class RandomWalkEnv:
    def __init__(self):
        self.states = range(1, 1001)
        self.terminal_states = {0: -1, 1001: 1} # state: reward
        self.start_state = 500
        self.current_state = None



    def reset(self):
        self.current_state = self.start_state
        return self.current_state

    def action(self):
        return np.random.choice(['left', 'right'])

    def approximate_value_function(self, weights, state):
        #V_hat(s; w0, w1) = w0 + w1 * s
        return weights[0] + weights[1] * (state / 1000)


    def step(self, action):
        if self.current_state in self.terminal_states:
            return self.current_state, 0, True # state, reward, done

        move = 1 if action == 'right' else -1
        next_state = self.current_state + move

        reward = 0
        done = False
        if next_state in self.terminal_states:
            reward = self.terminal_states[next_state]
            done = True
            self.current_state = next_state # Update to terminal state
        else:
            self.current_state = next_state


        return self.current_state, reward, done

    def is_terminal(self, state):
        return state in self.terminal_states


    def train(self, alpha, num_episodes, gamma):
        weights = np.random.rand(2) # w0, w1

        for ep in range(num_episodes):
            state = self.reset()
            done = False
            while not done:
                action = self.action()
                next_state, reward, done = self.step(action)
                v_hat = self.approximate_value_function(weights, state)
                v_hat_next_state = self.approximate_value_function(weights, next_state)
                target = reward
                if not done:
                    target = reward + gamma * v_hat_next_state
                td_error = target - v_hat

                weights[0] += alpha * td_error
                weights[1] += alpha * td_error * (state / 1000)

                state = next_state

        return weights

# %%
env = RandomWalkEnv()
w = env.train(alpha=0.001, num_episodes=1000, gamma=1.0)

# %%
import matplotlib.pyplot as plt

# Plot the true value function
true_states = np.arange(1, 1001)
true_values = true_states / 1001.0

plt.figure(figsize=(10, 6))
plt.plot(true_states, true_values, label='True Value Function (s/1001)', color='red')

# Plot the learned approximation
learned_values = [env.approximate_value_function(w, state) for state in true_states]
plt.plot(true_states, learned_values, label='Learned Approximation', color='blue')

plt.xlabel('State')
plt.ylabel('Value')
plt.title('True Value Function vs Learned Approximation (Random Walk)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **How does the approximation behave for small vs large states?**
# Using large states, the approximation using linear model has a hard time, especially at the ends.
#
# **How does the learning rate affect convergence?**
# It's seem to not affect that much from 0.001 to 0.01 because of linear function

# %% [markdown]
# # Exercise 3: Solving MountainCar with Tile Coding and SARSA
#
# ## Problem Description
# In this exercise, you will solve the **MountainCar-v0** environment from Gym using **tile coding** for function approximation and the **SARSA algorithm** for learning.
#
# The **Mountain Car problem**:
# - A car is stuck in a valley and is too weak to drive straight up to the goal.
# - It must build momentum by going back and forth until it can reach the goal at `position >= 0.5`.
# - **State space**: continuous (position, velocity).
# - **Actions**: {0: push left, 1: no push, 2: push right}.
# - **Reward**: -1 per step until the goal is reached.
# - **Episode ends**: when the car reaches the goal or after 200 steps.
#
# ---
#
# ## Step 1: Environment and Random Policy (with AI help)
# - Use an **AI tool (e.g., ChatGPT)** to generate starter code for:
#   - Creating the Gym environment (`MountainCar-v0`).
#   - Running a **random policy** (actions chosen randomly).
# - Run this code to confirm you can interact with the environment and see episode returns.
# - This will serve as a **baseline**.
# - **Important**: Do not use AI to implement the learning algorithm.
#
# ---
#
# ## Step 2: SARSA Algorithm with Function Approximation
# Implement **SARSA (on-policy TD control)** with the following steps:
#
# For each episode:
# 1. Initialize state `s`.
# 2. Choose action `a` using **ε-greedy** based on Q(s,a).
# 3. For each step:
#    - Take action `a`, observe `(s_next, r, done)`.
#    - Choose next action `a_next` using ε-greedy from `s_next`.
#    - Compute TD target:
#      ```
#      target = r + gamma * Q(s_next, a_next)
#      ```
#      (if `s_next` is terminal, then target = r).
#    - Compute TD error:
#      ```
#      delta = target - Q(s,a)
#      ```
#    - Update weights:
#      ```
#      w <- w + alpha * delta * x(s,a)
#      ```
#    - Update `s = s_next`, `a = a_next`.
# 4. End episode when the goal is reached or step limit is hit.
#
# ---
#
# ## Step 3: Experiments
# - Train the agent for 500–1000 episodes.
# - Plot **episode returns (sum of rewards)** vs episodes.
# - Compare with the random policy baseline:
#   - Does SARSA learn to consistently reach the goal?
#   - How many steps does it typically take?
#
# ---
#
# ## Deliverables
# - Python code for tile coding and SARSA.
# - Plot of returns vs episodes.
# - Plot the Value function
# - Short discussion (1–2 paragraphs):
#   - Effect of tile coding parameters (number of tilings, resolution).

# %%
# You can use the following code for tiling

import numpy as np


class TileCoderXY:
    """
    A TileCoder for function approximation that applies tile coding on the x and y coordinates
    of a 3D state. Instead of providing tile widths, the user provides the number of tiles per
    dimension. The tile widths are computed based on the state bounds and the number of tiles.
    The z coordinate is not used.
    """

    def __init__(self, num_tilings, tiles_per_dim, state_low, state_high):
        """
        Initialize the TileCoderXY.

        Parameters:
            num_tilings (int): Number of overlapping tilings.
            tiles_per_dim (array-like of 2 ints): Number of tiles along the x and y dimensions.
            state_low (array-like of 2 floats): Lower bounds for the x and y dimensions.
            state_high (array-like of 2 floats): Upper bounds for the x and y dimensions.
        """
        self.num_tilings = num_tilings
        self.tiles_per_dim = np.array(tiles_per_dim, dtype=int)
        self.state_low = np.array(state_low, dtype=float)
        self.state_high = np.array(state_high, dtype=float)

        # Compute the tile width for each dimension.
        # We assume that the grid spans exactly from state_low to state_high.
        # When there are N tiles, there are N-1 intervals between the boundaries.
        self.tile_width = (self.state_high - self.state_low) / (self.tiles_per_dim - 1)

        # Precompute an offset for each tiling to create overlapping grids.
        # self.offsets = [(i / self.num_tilings) * self.tile_width for i in range(self.num_tilings)]
        # self.offsets = self.compute_8_offsets()
        # self.offsets = np.stack(self._compute_offsets(), axis=0)  # shape: (num_tilings, dims)
        # Precompute offsets for each tiling.
        # For tiling i:
        #   offset_x = (((i + 0) % num_tilings) / num_tilings) * tile_width[0]
        #   offset_y = (((i + 1) % num_tilings) / num_tilings) * tile_width[1]
        offsets = np.empty((self.num_tilings, 2))
        for i in range(self.num_tilings):
            offsets[i, 0] = (((i + 0) % self.num_tilings) / self.num_tilings) * self.tile_width[0]
            offsets[i, 1] = (((i + 1) % self.num_tilings) / self.num_tilings) * self.tile_width[1]
        self.offsets = offsets


        # Precompute multiplier for flattening a 2D index.
        # For grid shape (N, M), flat index = x_index * M + y_index.
        self.multiplier = self.tiles_per_dim[1]

        # Initialize a weight vector for each tiling.
        num_tiles = np.prod(self.tiles_per_dim)
        self.weights = [np.zeros(num_tiles) for _ in range(self.num_tilings)]

    def save(self, file_name):
        np.savez(file_name + ".npz", weights=self.weights)

    def load(self, file_name):
        self.weights = np.load(file_name+".npz")["weights"]


    def compute_8_offsets(self):
        """
        Compute a list of offsets using a combination of cardinal and diagonal directions.
        The offsets include:
          - Center: [0, 0]
          - Cardinal: right, left, up, down (half-tile shifts)
          - Diagonal: up-right, up-left, down-right, down-left (half-tile shifts)

        If the number of tilings exceeds the number of unique offsets (9), the list is repeated.

        Returns:
            List of 2-element numpy arrays representing the offset for each tiling.
        """
        half_tile = self.tile_width / 8.0
        base_offsets = [
            np.array([0.0, 0.0]),  # Center (no shift)
            np.array([half_tile[0], 0.0]),  # Right
            np.array([-half_tile[0], 0.0]),  # Left
            np.array([0.0, half_tile[1]]),  # Up
            np.array([0.0, -half_tile[1]]),  # Down
            np.array([half_tile[0], half_tile[1]]),  # Up-right
            np.array([-half_tile[0], half_tile[1]]),  # Up-left
            np.array([half_tile[0], -half_tile[1]]),  # Down-right
            np.array([-half_tile[0], -half_tile[1]])  # Down-left
        ]
        offsets = []
        for i in range(self.num_tilings):
            offsets.append(base_offsets[i % len(base_offsets)])
        return offsets

    def get_tile_indices(self, state):
        """
        Compute the active tile indices for all tilings given a 2D state.

        Parameters:
            state (array-like of length 2): The input state [x, y].

        Returns:
            List of tuples (tiling_index, flat_tile_index) for each tiling.
        """
        state = np.array(state, dtype=float)  # shape: (2,)
        # Compute shifted states for all tilings in one vectorized operation.
        # Shape of shifted: (num_tilings, 2)
        shifted = (state - self.state_low) + self.offsets

        # Compute tile coordinates (integer indices) for each tiling.
        # Division is broadcasted over the offsets.
        tile_coords = (shifted / self.tile_width).astype(int)  # shape: (num_tilings, 2)

        # Clip to ensure indices are within bounds.
        tile_coords[:, 0] = np.clip(tile_coords[:, 0], 0, self.tiles_per_dim[0] - 1)
        tile_coords[:, 1] = np.clip(tile_coords[:, 1], 0, self.tiles_per_dim[1] - 1)

        # Compute flat indices for each tiling.
        # flat_index = x_index * (tiles_per_dim[1]) + y_index
        flat_indices = tile_coords[:, 0] * self.tiles_per_dim[1] + tile_coords[:, 1]

        # Return a list of (tiling_index, flat_index) tuples.
        return list(zip(range(self.num_tilings), flat_indices))


    def predict(self, state):
        """
        Compute the approximated function value for a given 3D state using tile coding on x and y.

        Parameters:
            state (array-like): The input state [x, y, z].

        Returns:
            float: The function approximation (sum of weights for the active tiles).
        """
        active_tiles = self.get_tile_indices(state)
        return sum(self.weights[tiling][idx] for tiling, idx in active_tiles)

    def update(self, state, target, alpha):
        """
        Update the weights given a state and target value.

        Parameters:
            state (array-like): The input state [x, y, z].
            target (float): The target function value.
            alpha (float): The overall learning rate.
        """
        prediction = self.predict(state)
        error = target - prediction
        # Distribute the learning rate equally among all tilings.
        alpha_per_tiling = alpha / self.num_tilings

        active_tiles = self.get_tile_indices(state)
        for tiling, idx in active_tiles:
            self.weights[tiling][idx] += alpha_per_tiling * error

# %%
import gymnasium as gym
import random
import numpy as np

class MountainCarAgent:
    def __init__(self):
        self.tilecoder_action = None



    def e_greedy_action_policy(self, state, epsilon=0.1):
        if random.random() < epsilon:
            return env.action_space.sample()
        else:
            return np.argmax([self.q_hat(state, a) for a in range(env.action_space.n)])



    def q_hat(self, state, action):
        return self.tilecoder_action[action].predict(state)


    def grad_q(self, state, action):
        return 1



    def load(self, file_name):
        self.tilecoder_action = []
        self.tilecoder_action[0].load(file_name + "_0")
        self.tilecoder_action[1].load(file_name + "_1")
        self.tilecoder_action[2].load(file_name + "_2")


    def show(self):
        state, _ = env.reset()
        done = False
        total_steps = 0
        total_reward = 0
        action = self.e_greedy_action_policy(state, epsilon=0)

        while not done:
            if total_steps > 200:
                break

            next_state, reward, terminated, truncated, info = env.step(action)

            done = terminated or truncated

            if done:
                break

            next_action = self.e_greedy_action_policy(next_state, epsilon=0)
            state = next_state
            action = next_action

            total_steps += 1
            total_reward += reward

        print(f"Total Reward: {total_reward}")





    def train(self, episodes, alpha, gamma, num_tilings, tiles_per_dim):

        self.tilecoder_action = [TileCoderXY(num_tilings=num_tilings, tiles_per_dim=tiles_per_dim, state_low=[-1.2, -0.07], state_high=[0.6, 0.07]) for _ in range(env.action_space.n)]

        reward_list = []
        for episode in range(episodes):
            state, _ = env.reset()
            done = False
            total_steps = 0
            total_reward = 0
            action = self.e_greedy_action_policy(state)

            while not done:
                if total_steps > 200:
                    break

                next_state, reward, terminated, truncated, info = env.step(action)

                done = terminated or truncated

                if done:
                    target = reward
                    break

                next_action = self.e_greedy_action_policy(next_state)
                target = reward + gamma * self.q_hat(next_state, next_action)
                self.tilecoder_action[action].update(state, target, alpha)

                state = next_state
                action = next_action

                total_steps += 1
                total_reward += reward

            if episode % 50 == 0:
                print(f"Episode {episode}, Total Reward: {total_reward}")

            reward_list.append(total_reward)

        print("Training completed.")

        self.tilecoder_action[0].save("mountain_car_tilecoder_action_0")
        self.tilecoder_action[1].save("mountain_car_tilecoder_action_1")
        self.tilecoder_action[2].save("mountain_car_tilecoder_action_2")

        return reward_list

# %%
env = gym.make('MountainCar-v0')
agent = MountainCarAgent()
reward_list = agent.train(episodes=10000, alpha=0.1, gamma=0.99, num_tilings=16, tiles_per_dim=[16, 16])

#agent.load("mountain_car_tilecoder_action")
#agent.show()
env.close()
# Out:
# Episode 0, Total Reward: -199.0
# Episode 50, Total Reward: -199.0
# Episode 100, Total Reward: -199.0
# Episode 150, Total Reward: -199.0
# Episode 200, Total Reward: -199.0
# Episode 250, Total Reward: -199.0
# Episode 300, Total Reward: -199.0
# Episode 350, Total Reward: -199.0
# Episode 400, Total Reward: -199.0
# Episode 450, Total Reward: -199.0
# Episode 500, Total Reward: -199.0
# Episode 550, Total Reward: -158.0
# Episode 600, Total Reward: -199.0
# Episode 650, Total Reward: -199.0
# Episode 700, Total Reward: -189.0
# Episode 750, Total Reward: -199.0
# Episode 800, Total Reward: -160.0
# Episode 850, Total Reward: -165.0
# Episode 900, Total Reward: -199.0
# Episode 950, Total Reward: -199.0
# Episode 1000, Total Reward: -185.0
# Episode 1050, Total Reward: -136.0
# Episode 1100, Total Reward: -155.0
# Episode 1150, Total Reward: -146.0
# Episode 1200, Total Reward: -115.0
# Episode 1250, Total Reward: -145.0
# Episode 1300, Total Reward: -114.0
# Episode 1350, Total Reward: -152.0
# Episode 1400, Total Reward: -150.0
# Episode 1450, Total Reward: -120.0
# Episode 1500, Total Reward: -150.0
# Episode 1550, Total Reward: -159.0
# Episode 1600, Total Reward: -107.0
# Episode 1650, Total Reward: -155.0
# Episode 1700, Total Reward: -89.0
# Episode 1750, Total Reward: -92.0
# Episode 1800, Total Reward: -156.0
# Episode 1850, Total Reward: -147.0
# Episode 1900, Total Reward: -119.0
# Episode 1950, Total Reward: -111.0
# Episode 2000, Total Reward: -150.0
# Episode 2050, Total Reward: -148.0
# Episode 2100, Total Reward: -88.0
# Episode 2150, Total Reward: -175.0
# Episode 2200, Total Reward: -163.0
# Episode 2250, Total Reward: -132.0
# Episode 2300, Total Reward: -153.0
# Episode 2350, Total Reward: -152.0
# Episode 2400, Total Reward: -141.0
# Episode 2450, Total Reward: -152.0
# Episode 2500, Total Reward: -154.0
# Episode 2550, Total Reward: -111.0
# Episode 2600, Total Reward: -97.0
# Episode 2650, Total Reward: -153.0
# Episode 2700, Total Reward: -153.0
# Episode 2750, Total Reward: -132.0
# Episode 2800, Total Reward: -157.0
# Episode 2850, Total Reward: -152.0
# Episode 2900, Total Reward: -159.0
# Episode 2950, Total Reward: -166.0
# Episode 3000, Total Reward: -92.0
# Episode 3050, Total Reward: -109.0
# Episode 3100, Total Reward: -151.0
# Episode 3150, Total Reward: -112.0
# Episode 3200, Total Reward: -87.0
# Episode 3250, Total Reward: -153.0
# Episode 3300, Total Reward: -112.0
# Episode 3350, Total Reward: -116.0
# Episode 3400, Total Reward: -160.0
# Episode 3450, Total Reward: -109.0
# Episode 3500, Total Reward: -130.0
# Episode 3550, Total Reward: -115.0
# Episode 3600, Total Reward: -110.0
# Episode 3650, Total Reward: -113.0
# Episode 3700, Total Reward: -157.0
# Episode 3750, Total Reward: -115.0
# Episode 3800, Total Reward: -114.0
# Episode 3850, Total Reward: -110.0
# Episode 3900, Total Reward: -146.0
# Episode 3950, Total Reward: -111.0
# Episode 4000, Total Reward: -141.0
# Episode 4050, Total Reward: -110.0
# Episode 4100, Total Reward: -163.0
# Episode 4150, Total Reward: -145.0
# Episode 4200, Total Reward: -108.0
# Episode 4250, Total Reward: -112.0
# Episode 4300, Total Reward: -108.0
# Episode 4350, Total Reward: -117.0
# Episode 4400, Total Reward: -109.0
# Episode 4450, Total Reward: -109.0
# Episode 4500, Total Reward: -113.0
# Episode 4550, Total Reward: -111.0
# Episode 4600, Total Reward: -110.0
# Episode 4650, Total Reward: -160.0
# Episode 4700, Total Reward: -108.0
# Episode 4750, Total Reward: -104.0
# Episode 4800, Total Reward: -108.0
# Episode 4850, Total Reward: -111.0
# Episode 4900, Total Reward: -109.0
# Episode 4950, Total Reward: -145.0
# Episode 5000, Total Reward: -108.0
# Episode 5050, Total Reward: -112.0
# Episode 5100, Total Reward: -110.0
# Episode 5150, Total Reward: -155.0
# Episode 5200, Total Reward: -88.0
# Episode 5250, Total Reward: -115.0
# Episode 5300, Total Reward: -108.0
# Episode 5350, Total Reward: -183.0
# Episode 5400, Total Reward: -110.0
# Episode 5450, Total Reward: -145.0
# Episode 5500, Total Reward: -109.0
# Episode 5550, Total Reward: -107.0
# Episode 5600, Total Reward: -110.0
# Episode 5650, Total Reward: -111.0
# Episode 5700, Total Reward: -161.0
# Episode 5750, Total Reward: -109.0
# Episode 5800, Total Reward: -112.0
# Episode 5850, Total Reward: -93.0
# Episode 5900, Total Reward: -125.0
# Episode 5950, Total Reward: -148.0
# Episode 6000, Total Reward: -106.0
# Episode 6050, Total Reward: -113.0
# Episode 6100, Total Reward: -90.0
# Episode 6150, Total Reward: -112.0
# Episode 6200, Total Reward: -158.0
# Episode 6250, Total Reward: -111.0
# Episode 6300, Total Reward: -156.0
# Episode 6350, Total Reward: -113.0
# Episode 6400, Total Reward: -89.0
# Episode 6450, Total Reward: -111.0
# Episode 6500, Total Reward: -146.0
# Episode 6550, Total Reward: -108.0
# Episode 6600, Total Reward: -106.0
# Episode 6650, Total Reward: -109.0
# Episode 6700, Total Reward: -109.0
# Episode 6750, Total Reward: -107.0
# Episode 6800, Total Reward: -109.0
# Episode 6850, Total Reward: -116.0
# Episode 6900, Total Reward: -108.0
# Episode 6950, Total Reward: -124.0
# Episode 7000, Total Reward: -177.0
# Episode 7050, Total Reward: -108.0
# Episode 7100, Total Reward: -106.0
# Episode 7150, Total Reward: -98.0
# Episode 7200, Total Reward: -161.0
# Episode 7250, Total Reward: -110.0
# Episode 7300, Total Reward: -113.0
# Episode 7350, Total Reward: -110.0
# Episode 7400, Total Reward: -183.0
# Episode 7450, Total Reward: -110.0
# Episode 7500, Total Reward: -109.0
# Episode 7550, Total Reward: -110.0
# Episode 7600, Total Reward: -144.0
# Episode 7650, Total Reward: -181.0
# Episode 7700, Total Reward: -111.0
# Episode 7750, Total Reward: -109.0
# Episode 7800, Total Reward: -109.0
# Episode 7850, Total Reward: -180.0
# Episode 7900, Total Reward: -127.0
# Episode 7950, Total Reward: -106.0
# Episode 8000, Total Reward: -109.0
# Episode 8050, Total Reward: -96.0
# Episode 8100, Total Reward: -183.0
# Episode 8150, Total Reward: -142.0
# Episode 8200, Total Reward: -113.0
# Episode 8250, Total Reward: -149.0
# Episode 8300, Total Reward: -106.0
# Episode 8350, Total Reward: -108.0
# Episode 8400, Total Reward: -199.0
# Episode 8450, Total Reward: -113.0
# Episode 8500, Total Reward: -111.0
# Episode 8550, Total Reward: -109.0
# Episode 8600, Total Reward: -108.0
# Episode 8650, Total Reward: -107.0
# Episode 8700, Total Reward: -109.0
# Episode 8750, Total Reward: -109.0
# Episode 8800, Total Reward: -112.0
# Episode 8850, Total Reward: -105.0
# Episode 8900, Total Reward: -112.0
# Episode 8950, Total Reward: -114.0
# Episode 9000, Total Reward: -107.0
# Episode 9050, Total Reward: -95.0
# Episode 9100, Total Reward: -107.0
# Episode 9150, Total Reward: -161.0
# Episode 9200, Total Reward: -196.0
# Episode 9250, Total Reward: -84.0
# Episode 9300, Total Reward: -114.0
# Episode 9350, Total Reward: -116.0
# Episode 9400, Total Reward: -150.0
# Episode 9450, Total Reward: -111.0
# Episode 9500, Total Reward: -151.0
# Episode 9550, Total Reward: -96.0
# Episode 9600, Total Reward: -109.0
# Episode 9650, Total Reward: -183.0
# Episode 9700, Total Reward: -98.0
# Episode 9750, Total Reward: -113.0
# Episode 9800, Total Reward: -157.0
# Episode 9850, Total Reward: -110.0
# Episode 9900, Total Reward: -111.0
# Episode 9950, Total Reward: -110.0
# Training completed.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plotting episode returns
# Assuming you have stored the episode returns in a list called `reward_list`
plt.figure(figsize=(10, 6))
plt.plot(range(len(reward_list)), reward_list, alpha=0.5, label='Episode Returns')

# Calculate and plot the rolling average of the episode returns
window_size = 100  # You can adjust the window size as needed
rolling_avg = np.convolve(reward_list, np.ones(window_size)/window_size, mode='valid')
plt.plot(range(window_size - 1, len(reward_list)), rolling_avg, label=f'Rolling Average ({window_size} episodes)', color='red')


plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.title('Episode Returns vs Episodes')
plt.legend()
plt.grid(True)
plt.show()

# To plot the value function, we can iterate over a grid of states and calculate the predicted value
# for each state and the optimal action.
position_space = np.linspace(env.observation_space.low[0], env.observation_space.high[0], 50)
velocity_space = np.linspace(env.observation_space.low[1], env.observation_space.high[1], 50)

value_function = np.zeros((len(position_space), len(velocity_space)))

for i, pos in enumerate(position_space):
    for j, vel in enumerate(velocity_space):
        state = np.array([pos, vel])
        # Calculate the value function for the state as the maximum Q-value over all actions
        value_function[i, j] = np.max([agent.q_hat(state, a) for a in range(env.action_space.n)])

plt.figure(figsize=(10, 8))
X, Y = np.meshgrid(position_space, velocity_space)
contour = plt.contourf(X, Y, -value_function.T, levels=50, cmap='viridis') # Use -value_function because reward is -1
plt.colorbar(contour, label='Negative Value (Steps to Goal)')
plt.xlabel('Position')
plt.ylabel('Velocity')
plt.title('Value Function Approximation (Negative Value)')
plt.grid(True)
plt.show()

# %% [markdown]
# If we choose to split in more subgrids, we will increase the precision, but it will require more training.
